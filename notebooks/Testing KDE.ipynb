# %%
import sys
sys.path.append("/auto/homes/fav25/jax/")
import jax
import jax.numpy as np
import jax.scipy as sc
import numpy
import matplotlib.pyplot as plt
from SC_IPFP.utils import *
import SC_IPFP.utils

# %%
X1 = numpy.random.randn(100).reshape(-1,1) - 5
X2 = numpy.random.randn(100).reshape(-1,1) + 5
X = np.concatenate((X1,X2), axis=0)
# Out:
# /auto/homes/fav25/jax/jax/lib/xla_bridge.py:116: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
plt.plot(X.flatten(), [0 for x in range(len(X.flatten()))], '.')

# %%
H = silvermans_rule(X)

# %%
x_star = np.linspace(-20,20, 500).reshape(-1,1)

penergy = kde_pdf_per_point(x_star, X, H)

# %%
plt.plot(x_star, penergy)
plt.plot(X.flatten(), [0 for x in range(len(X.flatten()))], '.')
