# %%
import torch
import math
from SC_IPFP.torch.utils import NN, log_kde_pdf_per_point, silvermans_rule
from SC_IPFP.torch.sde_solvers_time import solve_sde_RK


from tqdm.notebook import tqdm



import itertools
from functools import partial
# np = jax.numpy
import matplotlib.pyplot as plt

# %%
def solve_sde_RK(alfa=None, beta=None, X0=None, dt=1.0, N=100, t0=0.0,
                theta=None, noise=False, forwards=True):
    """
            Euler Mayurama method
    Syntax:
    ----------
    solve_sde(alfa=None, beta=None, X0=None, dt=None, N=100, t0=0, DW=None)
    Parameters:
    ----------
        alfa  : a  function with two arguments, the X state and the time
                defines the differential equation.
        beta  : a  function with two arguments, the X state and the time
                defines the stochastic part of the SDE.
        X0    : Initial conditions of the SDE. Mandatory for SDEs
                with variables > 1 (default: gaussian np.random)
        dt    : The timestep of the solution
                (default: 1)
        N     : The number of timesteps (defines the length of the timeseries)
                (default: 100)
        t0    : The initial time of the solution
                (default: 0)
    
    """
    
#     print(X0)
       
    if alfa is None or beta is None:
        raise ValueError("Error: SDE not defined.")

    n, d, *_ = X0.shape
    
    T = torch.tensor(dt * N).cuda()
    
    DWs  = torch.empty((n, N-1, d)).normal_(mean=0, std=1).cuda() * math.sqrt(dt)
    
    
    Y, ti = torch.zeros((n, N, d + 1)).double().cuda(), torch.arange(N).double().cuda()*dt + t0
    t0rep =  (
        t0 * torch.ones((X0.shape[0], 1)).double().cuda() if forwards
        else (T-t0) * torch.ones((X0.shape[0], 1)).double().cuda()
    )
#     Y[:, 0, :] =  torch.cat((X0, t0rep), axis=1 )
    ixs = torch.arange(3, dtype=torch.int64)
    Y = torch.cat((X0, t0rep), axis=1 )[:, None, :]

    N = int(N)
    
    T = dt * N
        
    for n in range(N-1):
        t = ti[n]
        a, DW_n = alfa(Y[:,n, :]),  DWs[:,n,:]
        newY = (  
            Y[:,n, :-1] + a * dt + beta * DW_n
        )
        
        trep = (
            t.repeat(newY.shape[0]).reshape(-1,1) if forwards
            else T - t.repeat(newY.shape[0]).reshape(-1,1)
        )
        
        tocat = torch.cat((newY, trep), dim=1)[:, None, :]
        Y = torch.cat((Y,tocat) , dim=1)
        if torch.isnan(Y).any() or torch.isinf(Y).any(): import pdb; pdb.set_trace()
#     import pdb; pdb.set_trace()
    return ti, Y

# %%
class cIPFP(object):
    
    def __init__(self, X_0, X_1, weights=[100], batch_size=None,  rng = None, rng_b = None, 
                nrng = None, number_time_steps=16, sde_solver=solve_sde_RK, sigma_sq=1, 
                step_size = 0.001, num_epochs = 10, momentum_mass = 0.9, create_network=None,
                log_prob=log_kde_pdf_per_point, optimizer=torch.optim.SGD):
        
        self.sde_solver = sde_solver
        
        self.number_time_steps = number_time_steps
        self.dt = 1.0 / number_time_steps
        
        
        self.batch_size_f = X_0.shape[0] if batch_size is None else batch_size
        self.batch_size_b = X_1.shape[0] if batch_size is None else batch_size
        with torch.cuda.device(0):
        
            self.X_0 = X_0
            self.X_1 = X_1

            self.H_0 = silvermans_rule(X_0)
            self.H_1 = silvermans_rule(X_1)

            _, self.dim = self.X_0.shape

            weights = weights + [self.dim]


            self.b_forward = NN(self.dim + 1, weights).double().cuda()
            self.b_backward = NN(self.dim + 1, weights).double().cuda()

            self.theta_f = list(self.b_forward.parameters())
            self.theta_b = list(self.b_backward.parameters())

            self.sigma = sigma_sq

            self.optimizer_f = optimizer(
                self.theta_f, lr=step_size
            )

            self.optimizer_b = optimizer(
                self.theta_b, lr=step_size
            )

            num_complete_batches_f, leftover_f = divmod(self.X_0.shape[0], self.batch_size_f)
            self.num_batches_f = num_complete_batches_f + bool(leftover_f)

            num_complete_batches_b, leftover_b = divmod(self.X_1.shape[0], self.batch_size_b)
            self.num_batches_b = num_complete_batches_b + bool(leftover_b)

            self.first_iter_fac = 0.0

            self.log_prob = log_prob

            self.burn_in = False
    
    def data_stream(self, forward=True):
        X = self.X_0 if forward else self.X_1
        
        batch_size = self.batch_size_f if forward else self.batch_size_b
        num_batches = self.num_batches_f if forward else self.num_batches_b
        
        num_train = self.X_0.shape[0] if forward else self.X_1.shape[0]
        while True:
            perm = torch.randperm(X.size()[0])
            for i in range(num_batches):
                batch_idx = perm[i * batch_size:(i + 1) * batch_size]
                yield X[batch_idx] 
        
    def loss_for_trajectory(self, Xt, forwards):
        n_, *_ = Xt.shape
        
        if not forwards :
            Xt = Xt.flip(1)
        
        if forwards:
            b_minus  = self.b_backward.forward( Xt)
            b_plus = self.b_forward.forward(Xt)
        else:
            b_minus  = self.first_iter_fac * self.b_backward.forward(Xt)
            b_plus = self.b_forward.forward(Xt)

            
        delta_Xt = Xt[:, 1:, :] - Xt[:, :-1, :]  
        
        sign = 1.0 if forwards else -1.0
        
        ito_integral = sign *  (b_plus[:, :-1,:] - b_minus[:, 1:,:])  * delta_Xt
        
        time_integral = sign *  (b_plus**2 - b_minus**2) * self.dt 
        
        out =  ito_integral.sum(axis=(1,2)) - 0.5 * time_integral.sum(axis=(1,2))
        
        return out


    def inner_loss_jit(self, batch,  
                       batch_terminal_empirical,
                       H,  forwards):
        
        b = (
            self.b_forward.forward
            if forwards else (lambda X: -self.b_backward.forward(X))
        )
        
        t, Xt, *W = self.sde_solver(
            b, self.sigma, batch, self.dt, 
            self.number_time_steps, 0,
            None, False, forwards
        )
        Ht = silvermans_rule(Xt[:,-1,:-1])
        H = silvermans_rule(batch_terminal_empirical)
        
        main_term = self.loss_for_trajectory(Xt, forwards)
        print( "term", torch.abs(main_term).max())
#         entropy = 0 #-log_kde_pdf_per_point(Xt[:,-1,:-1], Xt[:,-1,:-1], Ht) *  0
        if not self.burn_in:
            cross_entropy = -self.log_prob( Xt[:,-1,:-1], batch_terminal_empirical, H)             
        else:
            cross_entropy = -self.log_prob(batch_terminal_empirical, Xt[:,-1,:-1], Ht)
#             main_term = 0 

        J = torch.mean(main_term + 2.0 * cross_entropy )
        J = torch.squeeze(J)
        return J
    
    def inner_loss(self, batch, forwards=True):
        
        if self. burn_in:
            self.batch_terminal_empirical_burn = next(self.data_stream(forward=forwards))
            self.H_burn = self.H_0 if forwards else self.H_1
#         else:
        batch_terminal_empirical = next(self.data_stream(forward=not(forwards)))
        H = self.H_1 if forwards else self.H_0

        return self.inner_loss_jit(
            batch, batch_terminal_empirical,
            H,  forwards
        )

    def closure(self, X, forwards=True):
        """
        Close method required for pytorches CG and LBFGS optimizers
        :params X[torch.tensor]: nxdim  torch tensor representing dataset
        """
        
        opt = self.optimizer_f if forwards else self.optimizer_b
        
        opt.zero_grad()
        loss = self.inner_loss(X, forwards)
        loss.backward()
        return loss
    
    
    def fit(self, IPFP_iterations=10, sub_iterations=10, plot=False, burn_iterations=7):     
        
        name = str(self.optimizer_f).lower()
        bfgs_cg_flag  = "bfgs" in name or "cg" in name
        close_f, close_b =  [], []

        
        
        if plot: self.plot_trajectories()
        
        self.first_iter_fac = 0.0
        if burn_iterations > 0 : self.burn_in = True
            
        
        batches_f = self.data_stream(forward=True)
        batches_b = self.data_stream(forward=False)
        
        loss_b, loss_f = [], []
        for i in tqdm(range(IPFP_iterations + burn_iterations)):
            
            if i == burn_iterations:
                self.burn_in = False
                self.first_iter_fac = 0.0
            
            
            for k in range(sub_iterations):
                for _ in range(self.num_batches_b):
                    batch_b =  next(batches_b)
                    
                    if bfgs_cg_flag:
                        close_b = [lambda : self.closure(batch_b, False)]
                    lossb = self.inner_loss(
                        batch_b, False
                    )
                    lossb.backward()
                    self.optimizer_b.step(*close_b)
                print(f"loss b {lossb}")
            loss_b.append(lossb)

            self.first_iter_fac = 1.0
       
            for k in range(sub_iterations):
                for _ in range(self.num_batches_f):
                    batch_f =  next(batches_f)
                    if bfgs_cg_flag:
                        close_f = [lambda : self.closure(batch_f, True)]
                    lossf = self.inner_loss(
                        batch_f, True
                    )
                    
                    lossf.backward()
                    self.optimizer_f.step(*close_f)
  
                print(f"loss f {lossf}")
            loss_f.append(lossf)


            self.loss_f = loss_f
            self.loss_b = loss_b
            if plot: self.plot_trajectories()

        
        plt.plot(range(IPFP_iterations), loss_f, "g")
        plt.show()
        plt.plot(range(IPFP_iterations), loss_b, "b")
        plt.show()
        
    def plot_trajectories(self):
        bb = lambda X: -self.b_backward(X)

        t, Xts = c.sde_solver(
            self.b_forward.forward, self.sigma,
            self.X_0, self.dt,  self.number_time_steps, 0.0,
            self.theta_f, False, True
        )
        t_, Xts_ = c.sde_solver(
            bb, self.sigma, 
            self.X_1, self.dt, self.number_time_steps, 0.0, 
            self.theta_b, False, False
        )
        
        fn = 14
        fig, axs = plt.subplots(2,1,  sharey=False, figsize=(15,10))
        axs[1].set_xlabel("$t$", fontsize=fn)
        axs[1].set_ylabel("$x(t)$", fontsize=fn)
        axs[0].set_ylabel("$x(t)$", fontsize=fn)

        tt = axs[1].get_xticks()
        axs[1].set_xticks(tt.flatten() )
        axs[1].set_xticklabels(list(map (lambda x: '{0:.2f}'.format((x)), tt))[::-1])

        for i in range(n):
            label = "$\mathbb{Q}$: Forward process" if i == 0 else None
            axs[0].plot(t.cpu().flatten(), Xts[i,:,:-1].detach().cpu().numpy().flatten(), 'b', alpha=0.03,  label=label)


        for i in range(n):
            label = "$\mathbb{P}$: Reverse process" if i == 0 else None
            axs[1].plot(t_.cpu().flatten(), Xts_[i,:, :-1].detach().cpu().numpy().flatten(), 'r', alpha=0.03, label=label)

        axs[1].legend(fontsize=fn)
        axs[0].legend(fontsize=fn)

        plt.show()    
    
    #     @partial(jit, static_argnums=(0,2))
    def transport_batch(self, batch_x, forwards):
        theta = self.theta_f if forwards else self.theta_b    
        b = self.b_forward if forwards else  lambda X, theta: -self.b_backward(X, theta)

        t, Xt = self.sde_solver(
            alfa=b, beta=self.sigma, dt=self.dt, 
            X0=batch_x.reshape(-1,self.dim), N=self.number_time_steps, theta=theta
        )

        return Xt[:,-1,:]

# %%
import numpy.random as npr
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

n = 900
n_2 = int(n * 1.0 / 3)

X1 = npr.randn(n).reshape(-1,1) - 0
X21 = 0.6 * npr.randn(n_2).reshape(-1,1) + 20
X22 =  0.6 * npr.randn(n_2).reshape(-1,1) -20
X23 =  0.6 * npr.randn(n_2).reshape(-1,1) + 20

X2 = np.concatenate((X21, X22, X23), axis=0)
# X1, X2 = X2, X1

plt.plot(X2.flatten(), [0] * n, '.')
plt.plot(X1.flatten(), [0] * n, '.')

with torch.cuda.device(0):

    X1 = torch.tensor(X1).cuda()
    X2 = torch.tensor(X2).cuda()

# %%
c = cIPFP(X1, X2,  number_time_steps=100, batch_size=900 , step_size = 0.00001, weights=[20,20,20], rng = None)
# Out:
# /auto/homes/fav25/SC-IPFP/SC_IPFP/torch/utils.py:73: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   torch.nn.init.xavier_uniform(self.layers[i].weight)

# %%
torch.autograd.set_detect_anomaly(True)
c.fit(1900, 15, burn_iterations=0, plot=True)
# Out:
# term tensor(13.8239, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 2180.0807183750494
# term tensor(14.1152, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 2066.3109105285275
# term tensor(15.8052, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1887.3050553532275
# term tensor(16.7338, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1642.4226039757189
# term tensor(20.2692, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1358.8715136521203
# term tensor(21.9342, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1126.0972529120907
# term tensor(24.5713, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 922.6339854643517
# term tensor(25.8308, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 768.0511432571358
# term tensor(27.5551, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 677.9849056458537
# term tensor(28.9207, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 637.5327614982785
# term tensor(28.9249, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 612.687728266501
# term tensor(28.9230, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 587.5324878500185
# term tensor(28.8488, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 538.094234328393
# term tensor(28.7367, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 478.24758878339696
# term tensor(28.4596, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 425.44411644578815
# term tensor(97.0501, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.85312632162567
# term tensor(119.0671, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.73195996318785
# term tensor(142.1961, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.33775726439018
# term tensor(91.1977, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.26135663536476
# term tensor(112.5699, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 134.56007503447378
# term tensor(117.9676, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.79571760425034
# term tensor(112.2340, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.13785172645225
# term tensor(115.1634, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 134.9828628322979
# term tensor(122.1976, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 134.84493749657776
# term tensor(132.8706, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.454866092709
# term tensor(161.6888, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.24702811342883
# term tensor(115.9834, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 134.84373953690246
# term tensor(134.8499, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.5646206248941
# term tensor(186.3328, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 135.20826538025736
# term tensor(146.5397, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 134.89416886011938
# term tensor(555.2244, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 656.5196673282896
# term tensor(651.4810, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 651.2444202550641
# term tensor(742.9333, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 641.2649415262272
# term tensor(855.0514, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 634.91955619497
# term tensor(912.8412, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 633.6693832204868
# term tensor(1014.0924, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 637.4499406242412
# term tensor(1115.3971, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 660.5692274487732
# term tensor(1161.2114, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 690.9380262129278
# term tensor(1231.8209, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 724.8283463372019
# term tensor(1258.6983, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 758.3091285399881
# term tensor(1316.3148, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 782.8660948435387
# term tensor(1301.5142, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 797.9581357478052
# term tensor(1298.0268, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 799.2893406826346
# term tensor(1246.3681, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 791.9578871363424
# term tensor(1180.6382, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 770.6243635021848
# term tensor(535.9798, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 171.94871287997577
# term tensor(560.8611, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 173.7268412386049
# term tensor(644.4842, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 175.69867965124527
# term tensor(525.8001, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 176.3158540608699
# term tensor(692.9806, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 178.223125785723
# term tensor(569.3905, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 181.5436927027483
# term tensor(867.3011, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 181.99651807806038
# term tensor(619.9288, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 184.6621122701321
# term tensor(770.0050, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 187.2614791400814
# term tensor(1050.5684, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 191.65646592700682
# term tensor(797.3021, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 193.6350975109063
# term tensor(985.6726, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 195.54291102404855
# term tensor(798.7226, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 193.989440595835
# term tensor(1104.1854, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 201.49587964519483
# term tensor(839.1803, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 201.10253230941595
# term tensor(916.7423, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 661.0431273350405
# term tensor(759.8852, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 599.1017333786691
# term tensor(735.7635, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 529.1574413792326
# term tensor(812.8345, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 454.60919080300584
# term tensor(911.1753, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 377.01568583987836
# term tensor(993.6956, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 322.3283524875505
# term tensor(1123.1633, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 2388.8417554930193
# term tensor(1108.2425, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 484.2941288009622
# term tensor(1130.4768, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 736.2582124118037
# term tensor(1137.4298, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 912.2626043344076
# term tensor(1480.4704, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1084.9185118500848
# term tensor(1828.7122, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1255.8797479393802
# term tensor(2103.4029, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1426.237668908027
# term tensor(2394.9117, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1589.052161456463
# term tensor(2752.7419, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1735.793442310341
# term tensor(8921.7983, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 864.2168405649959
# term tensor(10608.9685, device='cuda:0', dtype=torch.float64,
#        grad_fn=<MaxBackward1>)
# loss f 955.6877791371139
# term tensor(9409.4841, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 899.0094839015302
# term tensor(8877.7012, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 835.8839482434895
# term tensor(8126.2941, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 734.8971539097096
# term tensor(7271.2123, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 664.5942167449448
# term tensor(6428.6559, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 553.9171942293376
# term tensor(5811.1455, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 499.98140876265455
# term tensor(5283.2079, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 452.19815839052814
# term tensor(4171.3590, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 409.96833737456114
# term tensor(4509.9981, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 384.6576025036052
# term tensor(3715.4507, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 376.4549892037807
# term tensor(3394.7492, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 382.4697267024192
# term tensor(3066.8763, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 351.7095934421003
# term tensor(3257.7494, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 348.0394000343349
# term tensor(3220.0878, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1962.324151457484
# term tensor(2866.3366, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1784.0796626496062
# term tensor(2583.1356, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1590.599786219979
# term tensor(2195.8480, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1386.3499662410345
# term tensor(1884.4199, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 1158.6929801062986
# term tensor(1507.2490, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 936.8401482011052
# term tensor(1155.4281, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 741.9776041066292
# term tensor(868.4284, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 548.6387222646908
# term tensor(585.9417, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 363.25861771054883
# term tensor(314.0249, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 213.60499458456243
# term tensor(158.7881, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 409.1689604736692
# term tensor(118.5719, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 682.5508957543659
# term tensor(96.5936, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 450.52104997658887
# term tensor(97.4366, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 376.72766202581744
# term tensor(115.3961, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 280.613003749725
# term tensor(20.6926, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 125.97946761352937
# term tensor(23.7692, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 124.89206076309769
# term tensor(19.8654, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 125.48733614426702
# term tensor(20.8245, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 124.82064131818548
# term tensor(16.1689, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 124.56064344658809
# term tensor(19.9627, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 123.95392853485721
# term tensor(18.8265, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 123.8829047874388
# term tensor(17.7795, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 122.6631140776048
# term tensor(17.5223, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 122.9274918020468
# term tensor(18.3400, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 121.97235437681235
# term tensor(20.2544, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 122.18282721606539
# term tensor(16.1526, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 121.63272654681924
# term tensor(19.5398, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 121.03742673527375
# term tensor(14.5703, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 119.96529077865358
# term tensor(15.8988, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 119.50414510731116
# term tensor(151.4859, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 207.81209546729357
# term tensor(189.2971, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 178.02803798929122
# term tensor(223.9550, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 170.34529577702136
# term tensor(224.7897, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 172.0324293893589
# term tensor(237.2500, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 173.54596512668783
# term tensor(249.0405, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 175.12481678028138
# term tensor(245.8526, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 176.60597970218262
# term tensor(253.8386, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 177.00968767406405
# term tensor(255.3936, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 176.51946939485163
# term tensor(252.1482, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 175.01128700597008
# term tensor(269.6817, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 173.46279038834368
# term tensor(249.1557, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 173.47860633993213
# term tensor(232.6746, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 177.01590846255291
# term tensor(224.0124, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 184.19657145347327
# term tensor(215.7223, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 194.5104220759857
# term tensor(6.9544, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 118.20314229845701
# term tensor(4.7963, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 118.26705238266669
# term tensor(8.4922, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 116.39071785794297
# term tensor(5.0058, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 115.32387385219887
# term tensor(7.2381, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 114.50865454034499
# term tensor(4.8761, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 113.85890475273173
# term tensor(8.6416, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 112.39928246267863
# term tensor(10.6612, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 110.64005248216642
# term tensor(5.7256, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 109.90276805777266
# term tensor(6.3373, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 108.22804184559376
# term tensor(8.8845, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 107.15337249121191
# term tensor(5.2779, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 105.17998010355934
# term tensor(4.9805, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 103.05502279441197
# term tensor(5.5716, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 102.10596328217244
# term tensor(8.0964, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 99.58011851572797
# term tensor(213.7539, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 206.81580591767596
# term tensor(217.1542, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 202.177994235515
# term tensor(226.9817, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 184.52925711774836
# term tensor(221.9816, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 167.72125615892233
# term tensor(233.7356, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 160.53432991131763
# term tensor(231.2952, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 164.33009576571473
# term tensor(254.5922, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 171.3007778667739
# term tensor(269.1071, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 180.8964800379226
# term tensor(256.8141, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 191.59427995408006
# term tensor(259.2414, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 201.68962956766615
# term tensor(265.3024, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 208.9412720704734
# term tensor(270.0726, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 214.7910443621116
# term tensor(269.7750, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 216.24913946920563
# term tensor(270.3225, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 213.07431514554713
# term tensor(250.1485, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 205.60311377207387
# term tensor(130.0611, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 113.9547040789925
# term tensor(137.2466, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 110.95565215440044
# term tensor(115.5770, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 108.53956395279992
# term tensor(142.3724, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 104.44202202260482
# term tensor(157.6196, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 101.63055360621803
# term tensor(164.2138, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 96.45025493321356
# term tensor(108.3304, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 90.19408690312855
# term tensor(123.7279, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 83.17494457803333
# term tensor(131.7851, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 77.58414091571439
# term tensor(129.0980, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 68.62301707626432
# term tensor(77.2021, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 60.396591477772446
# term tensor(42.6856, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 50.503175398808814
# term tensor(61.0879, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 46.513383004497975
# term tensor(223.1002, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 49.90957408692966
# term tensor(321.5909, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 65.87872508291241
# term tensor(248.5652, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 160.5044319133096
# term tensor(515.8893, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 288.9130569717934
# term tensor(1755.8325, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 870.3166696122311
# term tensor(202.5674, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 179.5462733564103
# term tensor(537.6786, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 315.21864090707953
# term tensor(1033.0813, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 471.45395070155973
# term tensor(1534.7890, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 605.3694433546365
# term tensor(1864.4247, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 696.9253549719509
# term tensor(2019.8959, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 729.8955117884668
# term tensor(1766.0540, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 669.6801680658202
# term tensor(1028.6276, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 472.953763698383
# term tensor(321.1469, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 226.97699886727614
# term tensor(353.0523, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 211.16811969842692
# term tensor(368.1114, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 208.59266606995203
# term tensor(340.4559, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 203.16732735844585
# term tensor(623.5988, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 192.97668724312726
# term tensor(697.7385, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 220.44851066956326
# term tensor(666.1050, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 235.29594573419644
# term tensor(559.9501, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 206.61576343914086
# term tensor(734.3236, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 178.25213146993556
# term tensor(605.0000, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 152.54550673788745
# term tensor(587.7904, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 139.46719640673598
# term tensor(557.8418, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 146.54886227441077
# term tensor(664.5651, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 143.16423773553356
# term tensor(625.5925, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 158.213845175928
# term tensor(694.8711, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 160.02117739121468
# term tensor(485.2098, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 170.6242187886986
# term tensor(660.1679, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 171.63027592333717
# term tensor(657.7645, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 179.1005865069362
# term tensor(836.7217, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss f 180.81239474403787
# term tensor(308.4322, device='cuda:0', dtype=torch.float64, grad_fn=<MaxBackward1>)
# loss b 221.5452068750758
# term tensor(3066392.1464, device='cuda:0', dtype=torch.float64,
#        grad_fn=<MaxBackward1>)
# loss b 4777540.116553506
# > <ipython-input-194-8640e814733e>(50)solve_sde_RK()
# -> for n in range(N-1):
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-205-81abab0719b7> in <module>()
#       1 torch.autograd.set_detect_anomaly(True)
# ----> 2 c.fit(1900, 15, burn_iterations=0, plot=True)
#
# <ipython-input-195-498bb14e77d7> in fit(self, IPFP_iterations, sub_iterations, plot, burn_iterations)
#     185                         close_b = [lambda : self.closure(batch_b, False)]
#     186                     lossb = self.inner_loss(
# --> 187                         batch_b, False
#     188                     )
#     189                     lossb.backward()
#
# <ipython-input-195-498bb14e77d7> in inner_loss(self, batch, forwards)
#     136         return self.inner_loss_jit(
#     137             batch, batch_terminal_empirical,
# --> 138             H,  forwards
#     139         )
#     140
#
# <ipython-input-195-498bb14e77d7> in inner_loss_jit(self, batch, batch_terminal_empirical, H, forwards)
#     107             b, self.sigma, batch, self.dt,
#     108             self.number_time_steps, 0,
# --> 109             None, False, forwards
#     110         )
#     111         Ht = silvermans_rule(Xt[:,-1,:-1])
#
# <ipython-input-194-8640e814733e> in solve_sde_RK(alfa, beta, X0, dt, N, t0, theta, noise, forwards)
#      48     T = dt * N
#      49
# ---> 50     for n in range(N-1):
#      51         t = ti[n]
#      52         a, DW_n = alfa(Y[:,n, :]),  DWs[:,n,:]
#
# <ipython-input-194-8640e814733e> in solve_sde_RK(alfa, beta, X0, dt, N, t0, theta, noise, forwards)
#      48     T = dt * N
#      49
# ---> 50     for n in range(N-1):
#      51         t = ti[n]
#      52         a, DW_n = alfa(Y[:,n, :]),  DWs[:,n,:]
#
# /usr/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      49             return # None
#      50         if event == 'line':
# ---> 51             return self.dispatch_line(frame)
#      52         if event == 'call':
#      53             return self.dispatch_call(frame, arg)
#
# /usr/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      68         if self.stop_here(frame) or self.break_here(frame):
#      69             self.user_line(frame)
# ---> 70             if self.quitting: raise BdbQuit
#      71         return self.trace_dispatch
#      72
#
# BdbQuit:

# %%
plt.plot(c.loss_f)
plt.show()
plt.plot(c.loss_b)

# %%
X = torch.linspace(-10, 10, 100).reshape(100, 1)
t = torch.ones(100).reshape(100, 1)
Xt = torch.cat((X,t), dim=1).cuda().double().requires_grad_()
print(Xt.shape)

torch.autograd.functional.jacobian(c.b_forward.forward, Xt).shape
# Out:
# torch.Size([100, 2])
# torch.Size([100, 1, 100, 2])

# %%
B = c.b_forward.forward(Xt)

# %%
c.b_forward.forward

test = torch.autograd.grad(B, Xt, torch.ones_like(B), retain_graph=True)[0].shape
# Out:
# torch.Size([100, 2])

# %%
xx = Xt[0,:].reshape(1,-1).double().cuda().requires_grad_()

test2 = c.b_forward.forward(xx)
test2
# Out:
# tensor([[-0.1342]], device='cuda:0', dtype=torch.float64,
#        grad_fn=<AddmmBackward>)

# %%
print(torch.autograd.grad(test2, xx, torch.ones_like(test2), retain_graph=True))
# Out:
# (tensor([[-0.0120, -0.5032]], device='cuda:0', dtype=torch.float64),)

# %%
def compute_jacobian(f, x, output_dims):
    '''
    Normal:
        f: input_dims -> output_dims
    Jacobian mode:
        f: output_dims x input_dims -> output_dims x output_dims
    '''
    repeat_dims = tuple(output_dims) + (1,) * len(x.shape)
    jac_x = x.detach().repeat(*repeat_dims)
    jac_x.requires_grad_()
    jac_y = f(jac_x)
    
    ml = torch.meshgrid([torch.arange(dim) for dim in output_dims])
    index = [m.flatten() for m in ml]
    gradient = torch.zeros(output_dims + output_dims)
    gradient.__setitem__(tuple(index)*2, 1)
    
    jac_y.backward(gradient)
        
    return jac_x.grad.data
